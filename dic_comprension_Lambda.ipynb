# %%
from tables.file import EArray
#Lista de contactos
import pandas as pd
import random
def menu(C,E,N,n):
  b=int(input("Menú:\n1)Añadir contacto\n2)Eliminar contacto\n3)Lista de contacto\n4)Darle emojis aleatorios\n"))
  if b==1:
    d=input("Nombre: ")
    f=d in N
    while f==True:
      d=input("Ya existe un contacto con ese nombre, escoja otro: ")
      f=d in C["Nombre"]
    e=input("Número: ")
    N.append(d)
    n.append(e)
  if b==2:
    o=int(input("1)Eliminar por nombre\n2)Eliminar por número\n"))
    if o==1:
      d=input("Nombre: ")
      f=d in N
      if f==False:
        print("No existe un contacto con ese nombre")
      else:
        i=N.index(d)
        N.pop(i)
        n.pop(i)
    if o==2:
      e=input("Número: ")
      h= e in N
      if h==False:
        print("No existe un contacto con ese número")
      else:
        i=n.index(e)
        N.pop(i)
        n.pop(i)
  if b==3:
    C={N[z]: n[z] for z in range(len(N)) }
    print(C)
  if b==4:
    C={N[z]: (n[z],E[random.randint(0,3)]) for z in range(len(N)) }
    print(pd.DataFrame.from_dict(C))
    
  return C
    
C={}
E=["B)",":)","<3",">:v"]
N=["juan","Kyle"]
n=["453","64782"]

a=True
while a==True:
  menu(C,E,N,n)

# %%
from tables.file import EArray
#Lista de contactos
import pandas as pd
import random
def menu(C,E,N,n):
  b=int(input("Menú:\n1)Añadir contacto\n2)Eliminar contacto\n3)Lista de contacto\n4)Darle emojis aleatorios\n"))
  if b==1:
    d=input("Nombre: ")
    f=d in N
    while f==True:
      d=input("Ya existe un contacto con ese nombre, escoja otro: ")
      f=d in C["Nombre"]
    e=input("Número: ")
    N.append(d)
    n.append(e)
  if b==2:
    o=int(input("1)Eliminar por nombre\n2)Eliminar por número\n"))
    if o==1:
      d=input("Nombre: ")
      f=d in N
      if f==False:
        print("No existe un contacto con ese nombre")
      else:
        i=N.index(d)
        N.pop(i)
        n.pop(i)
    if o==2:
      e=input("Número: ")
      h= e in N
      if h==False:
        print("No existe un contacto con ese número")
      else:
        i=n.index(e)
        N.pop(i)
        n.pop(i)
  if b==3:
    C=dict(map(lambda Nombre:(Nombre,n[N.index(Nombre)]),N))   
    print(C)
  if b==4:
    C=dict(map(lambda Nombre:(Nombre,(n[N.index(Nombre)],E[random.randint(0,3)])),N))
    print(pd.DataFrame.from_dict(C))
    
  return C
    
C={}
E=["B)",":)","<3",">:v"]
N=["juan","Kyle"]
n=["453","64782"]

a=True
while a==True:
  menu(C,E,N,n)
